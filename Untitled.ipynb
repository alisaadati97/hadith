# %%
import requests

headers = {
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="90", "Google Chrome";v="90"',
    'sec-ch-ua-mobile': '?0',
    'authorization': 'Bearer null',
    'Content-Type': 'application/json',
    'Access-Control-Allow-Origin': '*',
    'Accept': 'application/json, text/plain, */*',
    'Referer': 'https://hadith.inoor.ir/',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
    'DeviceType': 'web',
}

data = '{"hadithId":[103910],"searchPhrase":""}'

response = requests.post('https://hadith.inoor.ir/service/api/elastic/ElasticHadithById', headers=headers, data=data)
response.status_code
#resp #= response.json()
# Out:
# 429

# %%
print("-------")
#print(resp["data"][0]["qaelList"])
#print(resp["data"][0]["qaelList"][0]["title"])
#for key , val in resp["data"][0].items():
    #print("**")
    #print(key , "--" , val)

print(resp["data"][0]["text"])
raw = resp["data"][0]["text"]
print()
import re 
cleanr = re.compile('<.*?>')
cleantext = re.sub(cleanr, '', raw)
print(cleantext)

# %%
import requests

headers = {
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="90", "Google Chrome";v="90"',
    'sec-ch-ua-mobile': '?0',
    'authorization': 'Bearer null',
    'Content-Type': 'application/json',
    'Access-Control-Allow-Origin': '*',
    'Accept': 'application/json, text/plain, */*',
    'Referer': 'https://hadith.inoor.ir/',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
    'DeviceType': 'web',
}

data = '{"hadithId":[48113],"searchPhrase":""}'

response = requests.post('https://hadith.inoor.ir/service/api/elastic/ElasticHadithById', headers=headers, data=data)

response.json()
# Out:
# {'data': [{'highLight': [''],
#    'id': 349706,
#    'formatList': [{'order': 1,
#      'id': 1,
#      'title': 'روایات اصلی',
#      'tagName': 'Hadith',
#      'accessLevel': 0},
#     {'order': 2,
#      'id': 2,
#      'title': 'اسناد روایات',
#      'tagName': 'Document',
#      'accessLevel': 0},
#     {'order': 3,
#      'id': 3,
#      'title': 'راویان',
#      'tagName': 'Narrator',
#      'accessLevel': 0},
#     {'order': 4,
#      'id': 4,
#      'title': 'صادر کننده روایت',
#      'tagName': 'Exporter',
#      'accessLevel': 0},
#     {'order': 5,
#      'id': 5,
#      'title': 'چهارده معصوم',
#      'tagName': 'Innocent',
#      'accessLevel': 0},
#     {'order': 12,
#      'id': 12,
#      'title': 'امکنه',
#      'tagName': 'Place',
#      'accessLevel': 0}],
#    'groupTogetherList': [{'hadithId': 103907,
#      'vol': 1,
#      'pageNum': 11,
#      'sourceId': 1348,
#      'sourceMainTitle': 'الکافي',
#      'sourceShortTitle': 'الکافي',
#      'id': 6,
#      'centuryId': 4,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 2,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None},
#     {'hadithId': 310909,
#      'vol': 1,
#      'pageNum': 14,
#      'sourceId': 1453,
#      'sourceMainTitle': 'ثواب الأعمال و عقاب الأعمال',
#      'sourceShortTitle': 'ثواب الأعمال و عقاب الأعمال',
#      'id': 241994,
#      'centuryId': 4,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 2,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None},
#     {'hadithId': 180655,
#      'vol': 15,
#      'pageNum': 206,
#      'sourceId': 1405,
#      'sourceMainTitle': 'تفصیل وسائل الشیعة إلی تحصیل مسائل الشریعة',
#      'sourceShortTitle': 'وسائل الشیعة',
#      'id': 154832,
#      'centuryId': 12,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 0,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None},
#     {'hadithId': 23055,
#      'vol': 1,
#      'pageNum': 122,
#      'sourceId': 694,
#      'sourceMainTitle': 'الفصول المهمة فی أصول الأئمة (تکملة الوسائل)',
#      'sourceShortTitle': 'الفصول المهمة',
#      'id': 346582,
#      'centuryId': 12,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 0,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None},
#     {'hadithId': 48113,
#      'vol': 1,
#      'pageNum': 62,
#      'sourceId': 902,
#      'sourceMainTitle': 'إثبات الهداة بالنصوص و المعجزات',
#      'sourceShortTitle': 'اثبات الهداة',
#      'id': 349706,
#      'centuryId': 12,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 0,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None},
#     {'hadithId': 220959,
#      'vol': 1,
#      'pageNum': 91,
#      'sourceId': 1407,
#      'sourceMainTitle': 'بحار الأنوار الجامعة لدرر أخبار الأئمة الأطهار علیهم السلام',
#      'sourceShortTitle': 'بحار الأنوار',
#      'id': 65485,
#      'centuryId': 12,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 0,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None},
#     {'hadithId': 400419,
#      'vol': 5,
#      'pageNum': 382,
#      'sourceId': 1904,
#      'sourceMainTitle': 'تفسير نور الثقلين',
#      'sourceShortTitle': 'تفسير نور الثقلين',
#      'id': 386258,
#      'centuryId': 12,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 0,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None},
#     {'hadithId': 425012,
#      'vol': 13,
#      'pageNum': 355,
#      'sourceId': 1912,
#      'sourceMainTitle': 'تفسير کنز الدقائق و بحر الغرائب',
#      'sourceShortTitle': 'تفسير كنز الدقائق',
#      'id': 399885,
#      'centuryId': 12,
#      'accessLevel': 0,
#      'groupId': 18,
#      'section': 0,
#      'groupHadithCount': 8,
#      'sizeId': 0,
#      'sizeTitle': None,
#      'sizeJson': None,
#      'bookJson': None,
#      'qaelList': None}],
#    'tocInfo': [{'id': 128839,
#      'order': 1,
#      'sourceId': 902,
#      'accessLevel': 0,
#      'levelNum': 1,
#      'hadithCount': 1280,
#      'childCount': 1280,
#      'title': 'الجزء الأول',
#      'json': '{"Id":128839,"Title":"الجزء الأول","SourceId":"902","Order":1}',
#      'parentId': 0},
#     {'id': 128862,
#      'order': 2,
#      'sourceId': 902,
#      'accessLevel': 0,
#      'levelNum': 2,
#      'hadithCount': 1280,
#      'childCount': 1280,
#      'title': 'الباب الأول وجوب العمل بالعقل في إثبات حجية النقل',
#      'json': '{"Id":128862,"Title":"الباب الأول وجوب العمل بالعقل في إثبات حجية النقل","SourceId":"902","Order":2}',
#      'parentId': 128839}],
#    'hasTranslate': False,
#    'hasExplanation': False,
#    'hasSimilar': True,
#    'hasFamily': True,
#    'hadithId': 48113,
#    'qaelTitleList': 'امام صادق (علیه السلام)',
#    'textSample': '<Hadith><Document> - و عن <Narrator> احمد بن ادریس</Narrator> عن <Narrator> محمد بن حسان</Narrator> عن <Narrator> ابی محمد الرازی</Narrator> عن <Narrator> سیف بن عمیره</Narrator> عن <Narrator> اسحاق بن عمار</Narrator> قال قال <Exporter><Innocent> ابو عبد الله علیه السلام</Innocent></Exporter> : </Document> من کان عاقلا کان له دین، و من کان له دین دخل <Place> الجنه</Place> .</Hadith>',
#    'text': '<Hadith><Document> 3 - وَ عَنْ <Narrator> أَحْمَدَ بْنِ إِدْرِيسَ</Narrator> عَنْ <Narrator> مُحَمَّدِ بْنِ حَسَّانَ</Narrator> عَنْ <Narrator> أَبِي مُحَمَّدٍ اَلرَّازِيِّ</Narrator> عَنْ <Narrator> سَيْفِ بْنِ عَمِيرَةَ</Narrator> عَنْ <Narrator> إِسْحَاقَ بْنِ عَمَّارٍ</Narrator> قَالَ قَالَ <Exporter><Innocent> أَبُو عَبْدِ اَللَّهِ عَلَيْهِ اَلسَّلاَمُ</Innocent></Exporter> : </Document> مَنْ كَانَ عَاقِلاً كَانَ لَهُ دِينٌ، وَ مَنْ كَانَ لَهُ دِينٌ دَخَلَ <Place> اَلْجَنَّةَ</Place> .</Hadith>',
#    'shortText': '<Hadith> <Document> ... عَنْ <Narrator> إِسْحَاقَ بْنِ عَمَّارٍ</Narrator> قَالَ قَالَ <Exporter><Innocent> أَبُو عَبْدِ اَللَّهِ عَلَيْهِ اَلسَّلاَمُ</Innocent></Exporter> : </Document> مَنْ كَانَ عَاقِلاً كَانَ لَهُ دِينٌ، وَ مَنْ كَانَ لَهُ دِينٌ دَخَلَ <Place> اَلْجَنَّةَ</Place></Hadith>',
#    'textNoErab': '<Hadith><Document> 3 - و عن <Narrator> أحمد بن إدريس</Narrator> عن <Narrator> محمد بن حسان</Narrator> عن <Narrator> أبي محمد الرازي</Narrator> عن <Narrator> سيف بن عميرة</Narrator> عن <Narrator> إسحاق بن عمار</Narrator> قال قال <Exporter><Innocent> أبو عبد الله عليه السلام</Innocent></Exporter> : </Document> من كان عاقلا كان له دين، و من كان له دين دخل <Place> الجنة</Place> .</Hadith>',
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/1770/1/62',
#    'groupId': 0,
#    'groupHadithCount': 0,
#    'accessLevel': 0,
#    'qaelList': [{'order': 9,
#      'id': 6,
#      'qaelRoleId': 2,
#      'title': 'امام صادق (علیه السلام)',
#      'json': '{"Id":6,"Title":"امام صادق (علیه السلام)","Order":9}',
#      'roleTitle': 'صادر کننده'}],
#    'bookTitle': 'إثبات الهداة بالنصوص و المعجزات',
#    'bookTitleShort': 'اثبات الهداة',
#    'authorTitle': 'حر عاملی، محمد بن حسن',
#    'pageNum': 62,
#    'vol': 1,
#    'translateCount': 0,
#    'explanationCount': 0,
#    'hadithInbookCount': 95,
#    'hadithRelatedCount': 56,
#    'translateList': [],
#    'explanationList': []}],
#  'exception': None,
#  'message': None,
#  'status': 1,
#  'statusCode': 0,
#  'totalCount': 0,
#  'responseTime': 0,
#  'isSuccess': True}

# %%
import requests

headers = {
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="90", "Google Chrome";v="90"',
    'sec-ch-ua-mobile': '?0',
    'authorization': 'Bearer null',
    'Content-Type': 'application/json',
    'Access-Control-Allow-Origin': '*',
    'Accept': 'application/json, text/plain, */*',
    'Referer': 'https://hadith.inoor.ir/',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
    'DeviceType': 'web',
}

data = '{"hadithId":[103907],"searchPhrase":"","searchIn":"explanation"}'

response = requests.post('https://hadith.inoor.ir/service/api/elastic/ElasticHadithById', headers=headers, data=data)
resp = response.json()

resp = resp["data"][0]
resp
# Out:
# True
# {'highLight': [''],
#  'id': 0,
#  'formatList': None,
#  'groupTogetherList': None,
#  'tocInfo': None,
#  'hasTranslate': False,
#  'hasExplanation': False,
#  'hasSimilar': False,
#  'hasFamily': False,
#  'hadithId': 103907,
#  'qaelTitleList': None,
#  'textSample': None,
#  'text': None,
#  'shortText': None,
#  'textNoErab': None,
#  'noorLibLink': None,
#  'groupId': 0,
#  'groupHadithCount': 0,
#  'accessLevel': 0,
#  'qaelList': None,
#  'bookTitle': None,
#  'bookTitleShort': None,
#  'authorTitle': None,
#  'pageNum': 0,
#  'vol': 0,
#  'translateCount': 0,
#  'explanationCount': 0,
#  'hadithInbookCount': 0,
#  'hadithRelatedCount': 0,
#  'translateList': [],
#  'explanationList': [{'text': '<P> «احمد بن ادريس عن محمد بن حسان»،. و هو ابو عبد اللّه الرازى،قال النجاشى: يعرف بالزبينى يعرف و ينكر بين بين يروى عن الضعفاء كثيرا،و قال ابن الغضائرى: محمد بن حسان الرازى ابو جعفر ضعيف«صه» «عن ابى محمد الرازى». ،مهمل مجهول، «عن سيف بن عميرة». بفتح العين المهملة النخعى عربى كوفى ثقة،روى عن الصادق و الكاظم عليهما السلام«صه» «عن إسحاق بن عمار»،. بن حيان كان شيخا من اصحابنا ثقة روى عنهما عليهما السلام و كان فطحيا،قال الشيخ ثقة و اصله معتمد عليه و كذا قال النجاشى«صه» «قال:قال ابو عبد اللّه عليه السلام،من كان عاقلا كان له دين و من كان له دين دخل الجنة». كلامه عليه السلام فى صورة قياس منطقى اقترانى شرطى من الشكل الاول من اعلى ضروبه،لان المراد كل من كان عاقلا كان له دين،و كل من كان له دين دخل الجنة،ينتج:كل من كان عاقلا دخل الجنة. اما بيان الصغرى:فلان المراد من العاقل من كان جيد الروية صحيح الفكر فى امر معاشه و معاده فكان عاملا بمقتضى رأيه الصحيح و نظره الصائب فيلزمه ان يكون متدينا،اذ لو لم يكن فكره صحيحا و رأيه صوابا فى امر عاقبته لم يكن عاقلا بل جاهلا، و لو لم يعمل بمقتضى فكره الصحيح و رأيه الصواب كان سفيها غير عاقل،فثبت ان كل عاقل متدين. و اما الكبرى:فلان من كان عاقلا بصيرا متدينا عاملا بمقتضى عقله و ايمانه كان مستحقا بفضل اللّه و رحمته مستأهلا لجواره و جنته،و اللّه سبحانه اجل من ان يمنع المستحق عن فضله و احسانه،و هو الّذي اعطى الخلق و افاد الوجود بلا استحقاق سابق، فمع الاستحقاق و حصول الايمان و العمل بمقتضى العقل و العرفان كيف يقع الحرمان عن المغفرة و الرضوان و الفوز بالجنان؟</P>',
#    'textWithoutFormat': ' «احمد بن ادريس عن محمد بن حسان»،. و هو ابو عبد اللّه الرازى،قال النجاشى: يعرف بالزبينى يعرف و ينكر بين بين يروى عن الضعفاء كثيرا،و قال ابن الغضائرى: محمد بن حسان الرازى ابو جعفر ضعيف«صه» «عن ابى محمد الرازى». ،مهمل مجهول، «عن سيف بن عميرة». بفتح العين المهملة النخعى عربى كوفى ثقة،روى عن الصادق و الكاظم عليهما السلام«صه» «عن إسحاق بن عمار»،. بن حيان كان شيخا من اصحابنا ثقة روى عنهما عليهما السلام و كان فطحيا،قال الشيخ ثقة و اصله معتمد عليه و كذا قال النجاشى«صه» «قال:قال ابو عبد اللّه عليه السلام،من كان عاقلا كان له دين و من كان له دين دخل الجنة». كلامه عليه السلام فى صورة قياس منطقى اقترانى شرطى من الشكل الاول من اعلى ضروبه،لان المراد كل من كان عاقلا كان له دين،و كل من كان له دين دخل الجنة،ينتج:كل من كان عاقلا دخل الجنة. اما بيان الصغرى:فلان المراد من العاقل من كان جيد الروية صحيح الفكر فى امر معاشه و معاده فكان عاملا بمقتضى رأيه الصحيح و نظره الصائب فيلزمه ان يكون متدينا،اذ لو لم يكن فكره صحيحا و رأيه صوابا فى امر عاقبته لم يكن عاقلا بل جاهلا، و لو لم يعمل بمقتضى فكره الصحيح و رأيه الصواب كان سفيها غير عاقل،فثبت ان كل عاقل متدين. و اما الكبرى:فلان من كان عاقلا بصيرا متدينا عاملا بمقتضى عقله و ايمانه كان مستحقا بفضل اللّه و رحمته مستأهلا لجواره و جنته،و اللّه سبحانه اجل من ان يمنع المستحق عن فضله و احسانه،و هو الّذي اعطى الخلق و افاد الوجود بلا استحقاق سابق، فمع الاستحقاق و حصول الايمان و العمل بمقتضى العقل و العرفان كيف يقع الحرمان عن المغفرة و الرضوان و الفوز بالجنان؟',
#    'id': 52919,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P> «احمد بن ادريس عن محمد بن حسان»،. و هو ابو عبد اللّه الرازى،قال النجاشى: يعرف بالزبينى يعرف و ينكر بين بين يروى عن الضعفاء كثيرا،و قال ابن الغضائرى: محمد بن حسان الرازى ابو جعفر ضعيف«صه» «عن ابى محمد الرازى». ،مهمل مجهول، «عن سيف بن عميرة». بفتح العين المهملة النخعى عربى كوفى ثقة،روى عن الصادق و الكاظم عليهما السلام«صه» «عن إسحاق بن عمار»،. بن حيان كان شيخا من اصحابنا ثقة روى عنهما </P>\r\n</Translation>',
#    'isShorted': True,
#    'sourceId': 10879,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/6965/2/236',
#    'pageNum': 236,
#    'commentCount': 21769,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:36.0608854+03:30',
#    'sourceMainTitle': 'شرح أصول الکافي',
#    'sourceShortTitle': 'شرح أصول الکافي',
#    'authorAccessLevel': '0',
#    'authorTitle': 'صدر الدین شیرازی، محمد بن ابراهیم',
#    'authorId': 698},
#   {'text': '<P> الحديث السادس قوله«ره»:عن أبى محمد الرازى  حيث يقول رحمه اللّه تعالى في أسانيد هذا الكتاب«عن أبي محمد الرازي عن سيف بن عميرة»،يعني به جعفر بن يحيى العلاء القاضي بالري،و قد يكون المعني بأبي محمد الرازي في كتب الاخبار أحمد بن اسحاق الرازي، كما المعني بأبي علي القمي أحمد بن إسحاق الاشعرى.</P>',
#    'textWithoutFormat': ' الحديث السادس قوله«ره»:عن أبى محمد الرازى  حيث يقول رحمه اللّه تعالى في أسانيد هذا الكتاب«عن أبي محمد الرازي عن سيف بن عميرة»،يعني به جعفر بن يحيى العلاء القاضي بالري،و قد يكون المعني بأبي محمد الرازي في كتب الاخبار أحمد بن اسحاق الرازي، كما المعني بأبي علي القمي أحمد بن إسحاق الاشعرى.',
#    'id': 52920,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P> الحديث السادس قوله«ره»:عن أبى محمد الرازى حيث يقول رحمه اللّه تعالى في أسانيد هذا الكتاب«عن أبي محمد الرازي عن سيف بن عميرة»،يعني به جعفر بن يحيى العلاء القاضي بالري،و قد يكون المعني بأبي محمد الرازي في كتب الاخبار أحمد بن اسحاق الرازي، كما المعني بأبي علي القمي أحمد بن إسحاق الاشعرى.</P>\r\n</Translation>',
#    'isShorted': False,
#    'sourceId': 3637,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/14615/2/23',
#    'pageNum': 23,
#    'commentCount': 21770,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:36.0678865+03:30',
#    'sourceMainTitle': 'التعلیقة علی کتاب الکافی',
#    'sourceShortTitle': 'التعلیقة علی کتاب الکافی',
#    'authorAccessLevel': '0',
#    'authorTitle': 'میرداماد، محمدباقر بن محمد',
#    'authorId': 26},
#   {'text': '<P> شرح: الدِّين (به كسر دال): خوارى و فروتنى نزد كسى؛ و مراد اين جا، فروتنى نزد اللّٰه تعالى است به اقبال و اِدبار كه مذكور شد در حديث اوّلِ اين باب؛ و آن است ايمان حقيقى.<BR /> يعنى: گفت امام جعفر صادق عليه السّلام كه: هر كه هست خردمند، هست او را ايمان حقيقى.و هر كه هست او را ايمان حقيقى، داخل بهشت مىشود؛ چه غير مؤمن حقيقى كارش با اللّٰه تعالى است، چنانچه بيان شد در شرح «وَالْأَمْرُ فِي الشَّاكّ» تا آخر در خطبه.<BR /></P>',
#    'textWithoutFormat': ' شرح: الدِّين (به كسر دال): خوارى و فروتنى نزد كسى؛ و مراد اين جا، فروتنى نزد اللّٰه تعالى است به اقبال و اِدبار كه مذكور شد در حديث اوّلِ اين باب؛ و آن است ايمان حقيقى. يعنى: گفت امام جعفر صادق عليه السّلام كه: هر كه هست خردمند، هست او را ايمان حقيقى.و هر كه هست او را ايمان حقيقى، داخل بهشت مىشود؛ چه غير مؤمن حقيقى كارش با اللّٰه تعالى است، چنانچه بيان شد در شرح «وَالْأَمْرُ فِي الشَّاكّ» تا آخر در خطبه.',
#    'id': 52921,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P> شرح: الدِّين (به كسر دال): خوارى و فروتنى نزد كسى؛ و مراد اين جا، فروتنى نزد اللّٰه تعالى است به اقبال و اِدبار كه مذكور شد در حديث اوّلِ\u200c اين باب؛ و آن است ايمان حقيقى.<BR /> يعنى: گفت امام جعفر صادق عليه السّلام كه: هر كه هست خردمند، هست او را ايمان حقيقى.و هر كه هست او را ايمان حقيقى، داخل بهشت مى\u200cشود؛ چه غير مؤمن حقيقى كارش با اللّٰه تعالى است، چنانچه بيان شد در شرح «وَالْأَمْرُ <BR /></P>\r\n</Translation>',
#    'isShorted': True,
#    'sourceId': 3642,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/14620/1/187',
#    'pageNum': 187,
#    'commentCount': 21771,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:36.0768867+03:30',
#    'sourceMainTitle': 'صافی در شرح کافی',
#    'sourceShortTitle': 'صافی در شرح کافی',
#    'authorAccessLevel': '0',
#    'authorTitle': 'قزوینی، خلیل بن غازی',
#    'authorId': 2221},
#   {'text': '<P> هديّة: <BR /> يعني: (من كان عاقلاً) عن الحجّة المعصوم العاقل عن اللّٰه تبارك وتعالىٰ.والمراد أنّه لا دين لغير الإماميّة من البضع والسبعين،ولا يدخل الجنّة من هذه الاُمّة سوى الإماميّة. <BR />وقال برهان الفضلاء:<BR /> المراد بالدِّين هنا:الذلّ والاستكانة بالعبوديّة،والطاعة عند الأمر بالإقبال والإدبار،كما مرّ في بيان الحديث الأوّل،وهو الإيمان الحقيقي.<BR /> و«أبو محمّد الرازي»في سند هذا الحديث قيل:هو الحسن بن الجهم.وقيل:هو مجهول.<BR /></P>',
#    'textWithoutFormat': ' هديّة:  يعني: (من كان عاقلاً) عن الحجّة المعصوم العاقل عن اللّٰه تبارك وتعالىٰ.والمراد أنّه لا دين لغير الإماميّة من البضع والسبعين،ولا يدخل الجنّة من هذه الاُمّة سوى الإماميّة. وقال برهان الفضلاء: المراد بالدِّين هنا:الذلّ والاستكانة بالعبوديّة،والطاعة عند الأمر بالإقبال والإدبار،كما مرّ في بيان الحديث الأوّل،وهو الإيمان الحقيقي. و«أبو محمّد الرازي»في سند هذا الحديث قيل:هو الحسن بن الجهم.وقيل:هو مجهول.',
#    'id': 52922,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P> هديّة: <BR /> يعني: (من كان عاقلاً) عن الحجّة المعصوم العاقل عن اللّٰه تبارك وتعالىٰ\u200c.والمراد أنّه لا دين لغير الإماميّة من البضع والسبعين،ولا يدخل الجنّة من هذه الاُمّة سوى الإماميّة. <BR />وقال برهان الفضلاء:<BR /> المراد بالدِّين هنا:الذلّ\u200c والاستكانة بالعبوديّة،والطاعة عند الأمر بالإقبال والإدبار،كما مرّ في بيان الحديث الأوّل،وهو الإيمان الحقيقي.<BR /> و«أبو محمّد الرازي»في سند هذا <BR /></P>\r\n</Translation>',
#    'isShorted': True,
#    'sourceId': 3644,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/14623/1/201',
#    'pageNum': 201,
#    'commentCount': 21772,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:36.0848866+03:30',
#    'sourceMainTitle': 'الهدایا لشیعة أئمة الهدی',
#    'sourceShortTitle': 'الهدایا لشیعة أئمة الهدی',
#    'authorAccessLevel': '0',
#    'authorTitle': 'مجذوب تبریزی، محمد بن محمد رضا',
#    'authorId': 2223},
#   {'text': '<P> ضعيف. و أريد بالعقل هنا ما أريد به في الخبر الثالث، و القياس ينتج أن من كان متصفا بالعقل بهذا المعنى يدخل الجنة.</P>',
#    'textWithoutFormat': ' ضعيف. و أريد بالعقل هنا ما أريد به في الخبر الثالث، و القياس ينتج أن من كان متصفا بالعقل بهذا المعنى يدخل الجنة.',
#    'id': 188771,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P> ضعيف. و أريد بالعقل هنا ما أريد به في الخبر الثالث، و القياس ينتج أن من كان متصفا بالعقل بهذا المعنى يدخل الجنة.</P>\r\n</Translation>',
#    'isShorted': False,
#    'sourceId': 3636,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/5282/2/34',
#    'pageNum': 34,
#    'commentCount': 21773,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:36.0918861+03:30',
#    'sourceMainTitle': 'مرآة العقول في شرح أخبار آل الرسول',
#    'sourceShortTitle': 'مرآة العقول',
#    'authorAccessLevel': '0',
#    'authorTitle': 'مجلسی، محمدباقر بن محمدتقی',
#    'authorId': 367}]}

# %%
for key , val in resp.items():
    print("**")
    print(key , "--" , val)
# Out:
# **
# highLight -- ['']
# **
# id -- 0
# **
# formatList -- None
# **
# groupTogetherList -- None
# **
# tocInfo -- None
# **
# hasTranslate -- False
# **
# hasExplanation -- False
# **
# hasSimilar -- False
# **
# hasFamily -- False
# **
# hadithId -- 103907
# **
# qaelTitleList -- None
# **
# textSample -- None
# **
# text -- None
# **
# shortText -- None
# **
# textNoErab -- None
# **
# noorLibLink -- None
# **
# groupId -- 0
# **
# groupHadithCount -- 0
# **
# accessLevel -- 0
# **
# qaelList -- None
# **
# bookTitle -- None
# **
# bookTitleShort -- None
# **
# authorTitle -- None
# **
# pageNum -- 0
# **
# vol -- 0
# **
# translateCount -- 0
# **
# explanationCount -- 0
# **
# hadithInbookCount -- 0
# **
# hadithRelatedCount -- 0
# **
# translateList -- []
# **
# explanationList -- [{'text': '<P> «احمد بن ادريس عن محمد بن حسان»،. و هو ابو عبد اللّه الرازى،قال النجاشى: يعرف بالزبينى يعرف و ينكر بين بين يروى عن الضعفاء كثيرا،و قال ابن الغضائرى: محمد بن حسان الرازى ابو جعفر ضعيف«صه» «عن ابى محمد الرازى». ،مهمل مجهول، «عن سيف بن عميرة». بفتح العين المهملة النخعى عربى كوفى ثقة،روى عن الصادق و الكاظم عليهما السلام«صه» «عن إسحاق بن عمار»،. بن حيان كان شيخا من اصحابنا ثقة روى عنهما عليهما السلام و كان فطحيا،قال الشيخ ثقة و اصله معتمد عليه و كذا قال النجاشى«صه» «قال:قال ابو عبد اللّه عليه السلام،من كان عاقلا كان له دين و من كان له دين دخل الجنة». كلامه عليه السلام فى صورة قياس منطقى اقترانى شرطى من الشكل الاول من اعلى ضروبه،لان المراد كل من كان عاقلا كان له دين،و كل من كان له دين دخل الجنة،ينتج:كل من كان عاقلا دخل الجنة. اما بيان الصغرى:فلان المراد من العاقل من كان جيد الروية صحيح الفكر فى امر معاشه و معاده فكان عاملا بمقتضى رأيه الصحيح و نظره الصائب فيلزمه ان يكون متدينا،اذ لو لم يكن فكره صحيحا و رأيه صوابا فى امر عاقبته لم يكن عاقلا بل جاهلا، و لو لم يعمل بمقتضى فكره الصحيح و رأيه الصواب كان سفيها غير عاقل،فثبت ان كل عاقل متدين. و اما الكبرى:فلان من كان عاقلا بصيرا متدينا عاملا بمقتضى عقله و ايمانه كان مستحقا بفضل اللّه و رحمته مستأهلا لجواره و جنته،و اللّه سبحانه اجل من ان يمنع المستحق عن فضله و احسانه،و هو الّذي اعطى الخلق و افاد الوجود بلا استحقاق سابق، فمع الاستحقاق و حصول الايمان و العمل بمقتضى العقل و العرفان كيف يقع الحرمان عن المغفرة و الرضوان و الفوز بالجنان؟</P>', 'textWithoutFormat': ' «احمد بن ادريس عن محمد بن حسان»،. و هو ابو عبد اللّه الرازى،قال النجاشى: يعرف بالزبينى يعرف و ينكر بين بين يروى عن الضعفاء كثيرا،و قال ابن الغضائرى: محمد بن حسان الرازى ابو جعفر ضعيف«صه» «عن ابى محمد الرازى». ،مهمل مجهول، «عن سيف بن عميرة». بفتح العين المهملة النخعى عربى كوفى ثقة،روى عن الصادق و الكاظم عليهما السلام«صه» «عن إسحاق بن عمار»،. بن حيان كان شيخا من اصحابنا ثقة روى عنهما عليهما السلام و كان فطحيا،قال الشيخ ثقة و اصله معتمد عليه و كذا قال النجاشى«صه» «قال:قال ابو عبد اللّه عليه السلام،من كان عاقلا كان له دين و من كان له دين دخل الجنة». كلامه عليه السلام فى صورة قياس منطقى اقترانى شرطى من الشكل الاول من اعلى ضروبه،لان المراد كل من كان عاقلا كان له دين،و كل من كان له دين دخل الجنة،ينتج:كل من كان عاقلا دخل الجنة. اما بيان الصغرى:فلان المراد من العاقل من كان جيد الروية صحيح الفكر فى امر معاشه و معاده فكان عاملا بمقتضى رأيه الصحيح و نظره الصائب فيلزمه ان يكون متدينا،اذ لو لم يكن فكره صحيحا و رأيه صوابا فى امر عاقبته لم يكن عاقلا بل جاهلا، و لو لم يعمل بمقتضى فكره الصحيح و رأيه الصواب كان سفيها غير عاقل،فثبت ان كل عاقل متدين. و اما الكبرى:فلان من كان عاقلا بصيرا متدينا عاملا بمقتضى عقله و ايمانه كان مستحقا بفضل اللّه و رحمته مستأهلا لجواره و جنته،و اللّه سبحانه اجل من ان يمنع المستحق عن فضله و احسانه،و هو الّذي اعطى الخلق و افاد الوجود بلا استحقاق سابق، فمع الاستحقاق و حصول الايمان و العمل بمقتضى العقل و العرفان كيف يقع الحرمان عن المغفرة و الرضوان و الفوز بالجنان؟', 'id': 52919, 'hadithId': 103907, 'shortText': '<Translation>\r\n  <P> «احمد بن ادريس عن محمد بن حسان»،. و هو ابو عبد اللّه الرازى،قال النجاشى: يعرف بالزبينى يعرف و ينكر بين بين يروى عن الضعفاء كثيرا،و قال ابن الغضائرى: محمد بن حسان الرازى ابو جعفر ضعيف«صه» «عن ابى محمد الرازى». ،مهمل مجهول، «عن سيف بن عميرة». بفتح العين المهملة النخعى عربى كوفى ثقة،روى عن الصادق و الكاظم عليهما السلام«صه» «عن إسحاق بن عمار»،. بن حيان كان شيخا من اصحابنا ثقة روى عنهما </P>\r\n</Translation>', 'isShorted': True, 'sourceId': 10879, 'vol': 1, 'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/6965/2/236', 'pageNum': 236, 'commentCount': 21769, 'accessLevel': 0, 'languageId': 1, 'insertDate': '2021-01-02T19:45:36.0608854+03:30', 'sourceMainTitle': 'شرح أصول الکافي', 'sourceShortTitle': 'شرح أصول الکافي', 'authorAccessLevel': '0', 'authorTitle': 'صدر الدین شیرازی، محمد بن ابراهیم', 'authorId': 698}, {'text': '<P> الحديث السادس قوله«ره»:عن أبى محمد الرازى  حيث يقول رحمه اللّه تعالى في أسانيد هذا الكتاب«عن أبي محمد الرازي عن سيف بن عميرة»،يعني به جعفر بن يحيى العلاء القاضي بالري،و قد يكون المعني بأبي محمد الرازي في كتب الاخبار أحمد بن اسحاق ال ...

# %%
import requests

headers = {
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="90", "Google Chrome";v="90"',
    'sec-ch-ua-mobile': '?0',
    'authorization': 'Bearer null',
    'Content-Type': 'application/json',
    'Access-Control-Allow-Origin': '*',
    'Accept': 'application/json, text/plain, */*',
    'Referer': 'https://hadith.inoor.ir/',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
    'DeviceType': 'web',
}

data = '{"hadithId":[103907],"searchPhrase":"","searchIn":"translate"}'

response = requests.post('https://hadith.inoor.ir/service/api/elastic/ElasticHadithById', headers=headers, data=data)
response.json()
resp = response.json()

resp = resp["data"][0]
resp
# Out:
# True
# {'highLight': [''],
#  'id': 0,
#  'formatList': None,
#  'groupTogetherList': None,
#  'tocInfo': None,
#  'hasTranslate': False,
#  'hasExplanation': False,
#  'hasSimilar': False,
#  'hasFamily': False,
#  'hadithId': 103907,
#  'qaelTitleList': None,
#  'textSample': None,
#  'text': None,
#  'shortText': None,
#  'textNoErab': None,
#  'noorLibLink': None,
#  'groupId': 0,
#  'groupHadithCount': 0,
#  'accessLevel': 0,
#  'qaelList': None,
#  'bookTitle': None,
#  'bookTitleShort': None,
#  'authorTitle': None,
#  'pageNum': 0,
#  'vol': 0,
#  'translateCount': 0,
#  'explanationCount': 0,
#  'hadithInbookCount': 0,
#  'hadithRelatedCount': 0,
#  'translateList': [{'text': '<Translation>\r\n  <P> اسحاق بن عمار گويد: امام صادق عليه السلام فرمود: هر كه عاقل است دين دارد و كسى كه دين دارد ببهشت ميرود (پس هر كه عاقل است ببهشت ميرود).</P>\r\n</Translation>',
#    'textWithoutFormat': '\r\n   اسحاق بن عمار گويد: امام صادق عليه السلام فرمود: هر كه عاقل است دين دارد و كسى كه دين دارد ببهشت ميرود (پس هر كه عاقل است ببهشت ميرود).\r\n',
#    'id': 52916,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P> اسحاق بن عمار گويد: امام صادق عليه السلام فرمود: هر كه عاقل است دين دارد و كسى كه دين دارد ببهشت ميرود (پس هر كه عاقل است ببهشت ميرود).</P>\r\n</Translation>',
#    'isShorted': False,
#    'sourceId': 2646,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/14207/2/12',
#    'pageNum': 12,
#    'commentCount': 10323,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:35.9808855+03:30',
#    'sourceMainTitle': 'ترجمه اصول کافی',
#    'sourceShortTitle': 'اصول کافی / ترجمه مصطفوی',
#    'authorAccessLevel': '0',
#    'authorTitle': 'کلینی، محمد بن یعقوب',
#    'authorId': 2216},
#   {'text': '<Translation>\r\n  <P>6-امام صادق(عليه السّلام)فرمود:هر كه عاقل است دين دارد و هر كه دين دارد بهشت مى\u200cرود.</P>\r\n</Translation>',
#    'textWithoutFormat': '\r\n  6-امام صادق(عليه السّلام)فرمود:هر كه عاقل است دين دارد و هر كه دين دارد بهشت مى\u200cرود.\r\n',
#    'id': 52917,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P>6-امام صادق(عليه السّلام)فرمود:هر كه عاقل است دين دارد و هر كه دين دارد بهشت مى\u200cرود.</P>\r\n</Translation>',
#    'isShorted': False,
#    'sourceId': 2647,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/3712/1/35',
#    'pageNum': 35,
#    'commentCount': 10324,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:35.9918856+03:30',
#    'sourceMainTitle': 'ترجمه اصول کافی',
#    'sourceShortTitle': 'اصول كافى / ترجمه كمره اى',
#    'authorAccessLevel': '0',
#    'authorTitle': 'کلینی، محمد بن یعقوب',
#    'authorId': 2216},
#   {'text': '<Translation>\r\n  <P> 6-امام صادق عليه السّلام فرمود:هركس عقل دارد دين دارد و هركس دين دارد به بهشت مى\u200cرود(پس هر عاقلى به بهشت خواهد رفت)<BR /></P>\r\n</Translation>',
#    'textWithoutFormat': '\r\n   6-امام صادق عليه السّلام فرمود:هركس عقل دارد دين دارد و هركس دين دارد به بهشت مى\u200cرود(پس هر عاقلى به بهشت خواهد رفت)\r\n',
#    'id': 52918,
#    'hadithId': 103907,
#    'shortText': '<Translation>\r\n  <P> 6-امام صادق عليه السّلام فرمود:هركس عقل دارد دين دارد و هركس دين دارد به بهشت مى\u200cرود(پس هر عاقلى به بهشت خواهد رفت)<BR /></P>\r\n</Translation>',
#    'isShorted': False,
#    'sourceId': 14929,
#    'vol': 1,
#    'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/18515/2/5',
#    'pageNum': 5,
#    'commentCount': 10325,
#    'accessLevel': 0,
#    'languageId': 1,
#    'insertDate': '2021-01-02T19:45:36.0008872+03:30',
#    'sourceMainTitle': 'ترجمه اصول کافی',
#    'sourceShortTitle': 'اصول کافی / ترجمه آیت اللهی',
#    'authorAccessLevel': '0',
#    'authorTitle': 'کلینی، محمد بن یعقوب',
#    'authorId': 2216}],
#  'explanationList': []}

# %%
for key , val in resp.items():
    print("**")
    print(key , "--" , val)
# Out:
# **
# highLight -- ['']
# **
# id -- 0
# **
# formatList -- None
# **
# groupTogetherList -- None
# **
# tocInfo -- None
# **
# hasTranslate -- False
# **
# hasExplanation -- False
# **
# hasSimilar -- False
# **
# hasFamily -- False
# **
# hadithId -- 103907
# **
# qaelTitleList -- None
# **
# textSample -- None
# **
# text -- None
# **
# shortText -- None
# **
# textNoErab -- None
# **
# noorLibLink -- None
# **
# groupId -- 0
# **
# groupHadithCount -- 0
# **
# accessLevel -- 0
# **
# qaelList -- None
# **
# bookTitle -- None
# **
# bookTitleShort -- None
# **
# authorTitle -- None
# **
# pageNum -- 0
# **
# vol -- 0
# **
# translateCount -- 0
# **
# explanationCount -- 0
# **
# hadithInbookCount -- 0
# **
# hadithRelatedCount -- 0
# **
# translateList -- [{'text': '<Translation>\r\n  <P> اسحاق بن عمار گويد: امام صادق عليه السلام فرمود: هر كه عاقل است دين دارد و كسى كه دين دارد ببهشت ميرود (پس هر كه عاقل است ببهشت ميرود).</P>\r\n</Translation>', 'textWithoutFormat': '\r\n   اسحاق بن عمار گويد: امام صادق عليه السلام فرمود: هر كه عاقل است دين دارد و كسى كه دين دارد ببهشت ميرود (پس هر كه عاقل است ببهشت ميرود).\r\n', 'id': 52916, 'hadithId': 103907, 'shortText': '<Translation>\r\n  <P> اسحاق بن عمار گويد: امام صادق عليه السلام فرمود: هر كه عاقل است دين دارد و كسى كه دين دارد ببهشت ميرود (پس هر كه عاقل است ببهشت ميرود).</P>\r\n</Translation>', 'isShorted': False, 'sourceId': 2646, 'vol': 1, 'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/14207/2/12', 'pageNum': 12, 'commentCount': 10323, 'accessLevel': 0, 'languageId': 1, 'insertDate': '2021-01-02T19:45:35.9808855+03:30', 'sourceMainTitle': 'ترجمه اصول کافی', 'sourceShortTitle': 'اصول کافی / ترجمه مصطفوی', 'authorAccessLevel': '0', 'authorTitle': 'کلینی، محمد بن یعقوب', 'authorId': 2216}, {'text': '<Translation>\r\n  <P>6-امام صادق(عليه السّلام)فرمود:هر كه عاقل است دين دارد و هر كه دين دارد بهشت مى\u200cرود.</P>\r\n</Translation>', 'textWithoutFormat': '\r\n  6-امام صادق(عليه السّلام)فرمود:هر كه عاقل است دين دارد و هر كه دين دارد بهشت مى\u200cرود.\r\n', 'id': 52917, 'hadithId': 103907, 'shortText': '<Translation>\r\n  <P>6-امام صادق(عليه السّلام)فرمود:هر كه عاقل است دين دارد و هر كه دين دارد بهشت مى\u200cرود.</P>\r\n</Translation>', 'isShorted': False, 'sourceId': 2647, 'vol': 1, 'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/3712/1/35', 'pageNum': 35, 'commentCount': 10324, 'accessLevel': 0, 'languageId': 1, 'insertDate': '2021-01-02T19:45:35.9918856+03:30', 'sourceMainTitle': 'ترجمه اصول کافی', 'sourceShortTitle': 'اصول كافى / ترجمه كمره اى', 'authorAccessLevel': '0', 'authorTitle': 'کلینی، محمد بن یعقوب', 'authorId': 2216}, {'text': '<Translation>\r\n  <P> 6-امام صادق عليه السّلام فرمود:هركس عقل دارد دين دارد و هركس دين دارد به بهشت مى\u200cرود(پس هر عاقلى به بهشت خواهد رفت)<BR /></P>\r\n</Translation>', 'textWithoutFormat': '\r\n   6-امام صادق عليه السّلام فرمود:هركس عقل دارد دين دارد و هركس دين دارد به بهشت مى\u200cرود(پس هر عاقلى به بهشت خواهد رفت)\r\n', 'id': 52918, 'hadithId': 103907, 'shortText': '<Translation>\r\n  <P> 6-امام صادق عليه السّلام فرمود:هركس عقل دارد دين دارد و هركس دين دارد به بهشت مى\u200cرود(پس هر عاقلى به بهشت خواهد رفت)<BR /></P>\r\n</Translation>', 'isShorted': False, 'sourceId': 14929, 'vol': 1, 'noorLibLink': 'https://www.noorlib.ir/View/Fa/Book/BookView/Text/18515/2/5', 'pageNum': 5, 'commentCount': 10325, 'accessLevel': 0, 'languageId': 1, 'insertDate': '2021-01-02T19:45:36.0008872+03:30', 'sourceMainTitle': 'ترجمه اصول کافی', 'sourceShortTitle': 'اصول کافی / ترجمه آیت اللهی', 'authorAccessLevel': '0', 'authorTitle': 'کلینی، محمد بن یعقوب', 'authorId': 2216}]
# **
# explanationList -- []
